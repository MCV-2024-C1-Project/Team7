# %%
import pandas as pd

# %%
df_wavelet = pd.read_csv("wavelet_results_denoised_5.csv", index_col="Unnamed: 0")
df_gabor = pd.read_csv("gabor_results.csv", index_col="Unnamed: 0")

# %%
df_wavelet.sort_values(by="MAP@1", ascending=False).head(15)
# Out:
#     wavelet   direction   method     MAP@1     MAP@5
# 30      db1    Vertical   Cosine  0.100000  0.136111
# 31      db1    Vertical  Pearson  0.100000  0.136111
# 66  rbio1.1    Vertical   Cosine  0.100000  0.141111
# 67  rbio1.1    Vertical  Pearson  0.100000  0.141111
# 6   bior1.1    Vertical   Cosine  0.100000  0.136111
# 7   bior1.1    Vertical  Pearson  0.100000  0.136111
# 55     haar    Vertical  Pearson  0.100000  0.145556
# 54     haar    Vertical   Cosine  0.100000  0.145556
# 19    coif1    Vertical  Pearson  0.066667  0.167222
# 18    coif1    Vertical   Cosine  0.066667  0.167222
# 74     sym2  Horizontal   Cosine  0.033333  0.050000
# 22    coif1    Diagonal   Cosine  0.033333  0.033333
# 23    coif1    Diagonal  Pearson  0.033333  0.033333
# 75     sym2  Horizontal  Pearson  0.033333  0.050000
# 41     dmey    Vertical       L2  0.033333  0.033333

# %%
df_gabor.sort_values(by="MAP@1", ascending=False).head(15)
# Out:
#     num_angles distance_measure     MAP@1     MAP@5
# 0            1      correlation  0.033333  0.051111
# 12           4      correlation  0.033333  0.051111
# 32          32     intersection  0.033333  0.051111
# 30          32      correlation  0.033333  0.051111
# 26          16     intersection  0.033333  0.051111
# 24          16      correlation  0.033333  0.051111
# 20           8     intersection  0.033333  0.051111
# 14           4     intersection  0.033333  0.051111
# 18           8      correlation  0.033333  0.051111
# 8            2     intersection  0.033333  0.051111
# 2            1     intersection  0.033333  0.051111
# 6            2      correlation  0.033333  0.051111
# 9            2    bhattacharyya  0.000000  0.000000
# 5            1    kl-divergence  0.000000  0.000000
# 34          32        hellinger  0.000000  0.000000
