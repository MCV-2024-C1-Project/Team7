# %% [markdown]
# ### Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import data, color
from skimage.feature import local_binary_pattern
from skimage.io import imread
import os
import pickle
import cv2
import pandas as pd

from src.utils.images import load_images_from_directory, transform_images_color_space, split_image_into_quadrants
from src.utils.distance_matrix import create_distance_matrix, generate_results
from src.utils.ml_metrics import mapk

# %% [markdown]
# ### Constants

# %%
query_folder = "./data/qsd1_w3/non_augmented/"
bbdd_folder = "./data/BBDD"

# %% [markdown]
# ### Functions

# %%
def rescale_images(images, image_size):
    rescaled_images = []
    for image in images:
        rescaled_images.append(cv2.resize(image, image_size))
    return rescaled_images

def compute_block_lbp(block, radius, n_points, method):
    """
    Compute the LBP histogram for a single block of the image.
    """
    lbp = local_binary_pattern(block, n_points, radius, method=method)
    
    if method=="uniform":
        # Compute LBP histogram with uniform method (bins range from 0 to n_points + 2)
        hist, _ = np.histogram(lbp.ravel(), bins=np.arange(0, n_points + 3), density=True)
    else:
        # Compute LBP histogram with default or ror method
        hist, _ = np.histogram(lbp.ravel(), bins=2**n_points, density=True)
        
    return hist

def compute_images_block_lbp(images, radius, n_points, method, n_blocks):
    """
    Given a list of images, compute the LBP for each image by dividing
    each image into blocks, computing the LBP for each block, and concatenating
    the histograms of all blocks.
    
    Parameters:
    - images: list of loaded images (grayscale)
    - radius: radius for the LBP
    - n_points: number of neighbors (points) for the LBP
    - method: method for LBP ('uniform', 'ror', etc.)
    - n_blocks: number of blocks to divide the image into (1, 4, 16, 64)
    
    Returns:
    - List of concatenated histograms for each image.
    """
    image_histograms = []
    
    for image in images:
        
        # Divide the image into blocks
        blocks = split_image_into_quadrants(image, int(np.emath.logn(4, n_blocks))+1)
        
        # Compute LBP for each block and concatenate histograms
        concatenated_histogram = []
        for block in blocks:
            block_histogram = compute_block_lbp(block, radius, n_points, method)
            concatenated_histogram.append(block_histogram)
        
        # Concatenate all block histograms into a single feature vector for the image
        concatenated_histogram = np.concatenate(concatenated_histogram)
        image_histograms.append([concatenated_histogram.astype('float32')])
    
    return image_histograms

def compute_images_block_multi_lbp(images, method, n_blocks):
    image_histograms = []
    
    for image in images:
        
        # Divide the image into blocks
        blocks = split_image_into_quadrants(image, int(np.emath.logn(4, n_blocks))+1)
        
        # Compute LBP for each block and concatenate histograms
        concatenated_histogram = []
        for block in blocks:
            
            block_histogram = compute_block_lbp(block, 1, 8, method)
            concatenated_histogram.append(block_histogram)
            
            block_histogram = compute_block_lbp(block, 2, 8, method)
            concatenated_histogram.append(block_histogram)
            
            block_histogram = compute_block_lbp(block, 3, 12, method)
            concatenated_histogram.append(block_histogram)
        
        # Concatenate all block histograms into a single feature vector for the image
        concatenated_histogram = np.concatenate(concatenated_histogram)
        image_histograms.append([concatenated_histogram.astype('float32')])
    
    return image_histograms

# %%
def lbp_study(query_folder, bbdd_folder,
              colors = ["gray", "L", "V"],
              rescale_list = [True],
              radius_list = [1, 2, 3],
              points_list = [8, 10, 12],
              methods = ["default", "ror", "uniform"],
              num_blocks_list = [1, 4, 16, 64],
              distance_measures = ['intersection', 'correlation', 'bhattacharyya']):
    
    # Store results in a list that will later be converted to a dataframe
    full_results = []
    
    # Load query images
    query_images = load_images_from_directory(query_folder)

    # Load bbdd images
    bbdd_images = load_images_from_directory(bbdd_folder)
    
    # Load groundtruth
    gt_dir = os.path.join(query_folder, 'gt_corresps.pkl')
    with open(gt_dir, 'rb') as reader:
        ground_truth = pickle.load(reader)
    
    for color in colors:
        
        query_images_color = transform_images_color_space(query_images, color_space=color)
        bbdd_images_color = transform_images_color_space(bbdd_images, color_space=color)
        
        for rescale in rescale_list:
            
            if rescale:
                query_images_color = rescale_images(query_images_color, (256, 256))
                bbdd_images_color = rescale_images(bbdd_images_color, (256, 256))
        
            for radius, points in zip(radius_list, points_list):

                for method in methods:

                    for num_blocks in num_blocks_list:
                        
                        query_lbp_vectors = compute_images_block_lbp(query_images_color, radius, points, method, num_blocks)
                        bbdd_lbp_vectors = compute_images_block_lbp(bbdd_images_color, radius, points, method, num_blocks)
                        
                        for distance_measure in distance_measures:
                            
                            # Print current combination
                            print(f"{color}, rescale={rescale}, {radius}-{points}, {method}, {num_blocks}, {distance_measure}", end=" ")

                            # Calculate distance matrix
                            distance_matrix = create_distance_matrix(query_lbp_vectors, 
                                                                     bbdd_lbp_vectors,
                                                                     distance_measure,
                                                                     normalize=None)
                            # Generate sorted results
                            results = generate_results(distance_matrix, distance_measure)

                            # Calculate metrics
                            mapk_val_1 = mapk(ground_truth, results, 1)
                            mapk_val_5 = mapk(ground_truth, results, 5)

                            # Print metrics for current combination
                            print(f"-- MAPK@{1}: {mapk_val_1} -- MAPK@{5}: {mapk_val_5}")

                            # Save current combination parameters and results
                            combination_results = {}
                            combination_results['Color'] = color
                            combination_results['Rescale'] = rescale
                            combination_results['Radius'] = radius
                            combination_results['Points'] = points
                            combination_results['Method'] = method
                            combination_results['Blocks'] = num_blocks
                            combination_results['Distance'] = distance_measure
                            combination_results['MAP@1'] = mapk_val_1
                            combination_results['MAP@5'] = mapk_val_5
                            full_results.append(combination_results)
                    
    # Save results to csv via df
    full_results_df = pd.DataFrame(full_results)
    full_results_df.to_csv("lbp_study_results.csv", index=False)
    
    return full_results_df

# %%
results_df = lbp_study(query_folder, bbdd_folder,
              colors = ["gray", "L", "V"],
              rescale_list = [True],
              radius_list = [1, 2, 3],
              points_list = [8, 10, 12],
              methods = ["default", "ror", "uniform"],
              num_blocks_list = [1, 4, 16, 64],
              distance_measures = ['intersection', 'correlation', 'bhattacharyya'])
# Out:
# gray, rescale=True, 1-8, default, 1, intersection -- MAPK@1: 0.23333333333333334 -- MAPK@5: 0.2861111111111111
# gray, rescale=True, 1-8, default, 1, correlation -- MAPK@1: 0.23333333333333334 -- MAPK@5: 0.2816666666666666
# gray, rescale=True, 1-8, default, 1, bhattacharyya -- MAPK@1: 0.3 -- MAPK@5: 0.325
# gray, rescale=True, 1-8, default, 4, intersection -- MAPK@1: 0.4 -- MAPK@5: 0.45111111111111113
# gray, rescale=True, 1-8, default, 4, correlation -- MAPK@1: 0.4 -- MAPK@5: 0.4305555555555555
# gray, rescale=True, 1-8, default, 4, bhattacharyya -- MAPK@1: 0.4666666666666667 -- MAPK@5: 0.5055555555555555
# gray, rescale=True, 1-8, default, 16, intersection -- MAPK@1: 0.6 -- MAPK@5: 0.6261111111111111
# gray, rescale=True, 1-8, default, 16, correlation -- MAPK@1: 0.5666666666666667 -- MAPK@5: 0.5833333333333334
# gray, rescale=True, 1-8, default, 16, bhattacharyya -- MAPK@1: 0.6 -- MAPK@5: 0.6261111111111111
# gray, rescale=True, 1-8, default, 64, intersection -- MAPK@1: 0.8333333333333334 -- MAPK@5: 0.8955555555555555
# gray, rescale=True, 1-8, default, 64, correlation -- MAPK@1: 0.7333333333333333 -- MAPK@5: 0.801111111111111
# gray, rescale=True, 1-8, default, 64, bhattacharyya -- MAPK@1: 0.7666666666666667 -- MAPK@5: 0.8455555555555556
# gray, rescale=True, 1-8, ror, 1, intersection -- MAPK@1: 0.06666666666666667 -- MAPK@5: 0.09444444444444443
# gray, rescale=True, 1-8, ror, 1, correlation -- MAPK@1: 0.06666666666666667 -- MAPK@5: 0.09666666666666666
# gray, rescale=True, 1-8, ror, 1, bhattacharyya -- MAPK@1: 0.1 -- MAPK@5: 0.11666666666666667
# gray, rescale=True, 1-8, ror, 4, intersection -- MAPK@1: 0.2 -- MAPK@5: 0.22777777777777777
# gray, rescale=True, 1-8, ror, 4, correlation -- MAPK@1: 0.2 -- MAPK@5: 0.21777777777777776
# gray, rescale=True, 1-8, ror, 4, bhattacharyya -- MAPK@1: 0.2 -- MAPK@5: 0.23444444444444443
# gray, rescale=True, 1-8, ror, 16, intersection -- MAPK@1: 0.3333333333333333 -- MAPK@5: 0.36333333333333334
# gray, rescale=True, 1-8, ror, 16, correlation -- MAPK@1: 0.3333333333333333 -- MAPK@5: 0.38999999999999996
# gray, rescale=True, 1-8, ror, 16, bhattacharyya -- MAPK@1: 0.3333333333333333 -- MAPK@5: 0.34833333333333333
# gray, rescale=True, 1-8, ror, 64, intersection -- MAPK@1: 0.4666666666666667 -- MAPK@5: 0.5
# gray, rescale=True, 1-8, ror, 64, correlation -- MAPK@1: 0.5333333333333333 -- MAPK@5: 0.55
# gray, rescale=True, 1-8, ror, 64, bhattacharyya -- MAPK@1: 0.5 -- MAPK@5: 0.5222222222222223
# gray, rescale=True, 1-8, uniform, 1, intersection -- MAPK@1: 0.06666666666666667 -- MAPK@5: 0.0861111111111111
# gray, rescale=True, 1-8, uniform, 1, correlation -- MAPK@1: 0.06666666666666667 -- MAPK@5: 0.07777777777777777
# gray, rescale=True, 1-8, uniform, 1, bhattacharyya -- MAPK@1: 0.06666666666666667 -- MAPK@5: 0.09000000000000001
# gray, rescale=True, 1-8, uniform, 4, intersection -- MAPK@1: 0.2 -- MAPK@5: 0.21777777777777776
# gray, rescale=True, 1-8, uniform, 4, correlation -- MAPK@1: 0.2 -- MAPK@5: 0.22444444444444445
# gray, rescale=True, 1-8, uniform, 4, bhattacharyya -- MAPK@1: 0.2 -- MAPK@5: 0.21333333333333335
# gray, rescale=True, 1-8, uniform, 16, intersection -- MAPK@1: 0.3333333333333333 -- MAPK@5: 0.34833333333333333
# gray, rescale=True, 1-8, uniform, 16, correlation -- MAPK@1: 0.3 -- MAPK@5: 0.3416666666666667
# gray, rescale=True, 1-8, uniform, 16, bhattacharyya -- MAPK@1: 0.3 -- MAPK@5: 0.33055555555555555
# gray, rescale=True, 1-8, uniform, 64, intersection -- MAPK@1: 0.4666666666666667 -- MAPK@5: 0.48333333333333334
# gray, rescale=True, 1-8, uniform, 64, correlation -- MAPK@1: 0.5 -- MAPK@5: 0.5333333333333333
# gray, rescale=True, 1-8, uniform, 64, bhattacharyya -- MAPK@1: 0.4666666666666667 -- MAPK@5: 0.4944444444444444
# gray, rescale=True, 2-10, default, 1, intersection -- MAPK@1: 0.43333333333333335 -- MAPK@5: 0.5011111111111111
# gray, rescale=True, 2-10, default, 1, correlation -- MAPK@1: 0.4 -- MAPK@5: 0.45
# gray, rescale=True, 2-10, default, 1, bhattacharyya -- MAPK@1: 0.5 -- MAPK@5: 0.5427777777777777
# gray, rescale=True, 2-10, default, 4, intersection -- MAPK@1: 0.7 -- MAPK@5: 0.736111111111111
# gray, rescale=True, 2-10, default, 4, correlation -- MAPK@1: 0.6666666666666666 -- MAPK@5: 0.7161111111111111
# gray, rescale=True, 2-10, default, 4, bhattacharyya -- MAPK@1: 0.6666666666666666 -- MAPK@5: 0.7333333333333333
# gray, rescale=True, 2-10, default, 16, intersection -- MAPK@1: 0.9 -- MAPK@5: 0.9333333333333333
# gray, rescale=True, 2-10, default, 16, correlation -- MAPK@1: 0.8666666666666667 -- MAPK@5: 0.9333333333333333
# gray, rescale=True, 2-10, default, 16, bhattacharyya -- MAPK@1: 0.8 -- MAPK@5: 0.8444444444444446
# gray, rescale=True, 2-10, default, 64, intersection -- MAPK@1: 1.0 -- MAPK@5: 1.0
# gray, rescale=True, 2-10, default, 64, correlation -- MAPK@1: 1.0 -- MAPK@5: 1.0
# gray, rescale=True, 2-10, default, 64, bhattacharyya -- MAPK@1: 1.0 -- MAPK@5: 1.0
# gray, rescale=True, 2-10, ror, 1, intersection -- MAPK@1: 0.13333333333333333 -- MAPK@5: 0.17777777777777776
# gray, rescale=True, 2-10, ror, 1, correlation -- MAPK@1: 0.13333333333333333 -- MAPK@5: 0.17333333333333334
# gray, rescale=True, 2-10, ror, 1, bhattacharyya -- MAPK@1: 0.16666666666666666 -- MAPK@5: 0.21333333333333335
# gray, rescale=True, 2-10, ror, 4, intersection -- MAPK@1: 0.3333333333333333 -- MAPK@5: 0.35833333333333334
# gray, rescale=True, 2-10, ror, 4, correlation -- MAPK@1: 0.3333333333333333 -- MAPK@5: 0.375
# gray, rescale=True, 2-10, ror, 4, bhattacharyya -- MAPK@1: 0.3 -- MAPK@5: 0.375
# gray, rescale=True, 2-10, ror, 16, intersection -- MAPK@1: 0.4666666666666667 -- MAPK@5: 0.5
# gray, rescale=True, 2-10, ror, 16, correlation -- MAPK@1: 0.4666666666666667 -- MAPK@5: 0.53
# gray, rescale=True, 2-10, ror, 16, bhattacharyya -- MAPK@1: 0.5 -- MAPK@5: 0.5111111111111112
# gray, rescale=True, 2-10, ror, 64, intersection -- MAPK@1: 0.7 -- MAPK@5: 0.75
# gray, rescale=True, 2-10, ror, 64, correlation -- MAPK@1: 0.7 -- MAPK@5: 0.7666666666666667
# gray, rescale=True, 2-10, ror, 64, bhattacharyya -- MAPK@1: 0.6333333333333333 -- MAPK@5: 0.6611111111111111
# gray, rescale=True, 2-10, uniform, 1, intersection -- MAPK@1: 0.1 -- MAPK@5: 0.115
# gray, rescale=True, 2-10, uniform, 1, correlation -- MAPK@1: 0.1 -- MAPK@5: 0.12611111111111112
# gray, rescale=True, 2-10, uniform, 1, bhattacharyya -- MAPK@1: 0.13333333333333333 -- MAPK@5: 0.15833333333333333
# gray, rescale=True, 2-10, uniform, 4, intersection -- MAPK@1: 0.3 -- MAPK@5: 0.31777777777777777
# gray, rescale=True, 2-10, uniform, 4, correlation -- MAPK@1: 0.26666666666666666 -- MAPK@5: 0.2944444444444444
# gray, rescale=True, 2-10, uniform, 4, bhattacharyya -- MAPK@1: 0.3333333333333333 -- MAPK@5: 0.35833333333333334
# gray, rescale=True, 2-10, uniform, 16, intersection -- MAPK@1: 0.43333333333333335 -- MAPK@5: 0.4722222222222222
# gray, rescale=True, 2-10, uniform, 16, correlation -- MAPK@1: 0.4666666666666667 -- MAPK@5: 0.5666666666666667
# gray, rescale=True, 2-10, uniform, 16, bhattacharyya -- MAPK@1: 0.4666666666666667 -- MAPK@5: 0.49444444444444446
# gray, rescale=True, 2-10, uniform, 64, intersection -- MAPK@1: 0.6333333333333333 -- MAPK@5: 0.6694444444444444
# gray, rescale=True, 2-10, uniform, 64, correlation -- MAPK@1: 0.7333333333333333 -- MAPK@5: 0.7666666666666667
# gray, rescale=True, 2-10, uniform, 64, bhattacharyya -- MAPK@1: 0.6 -- MAPK@5: 0.6527777777777778
# gray, rescale=True, 3-12, default, 1, intersection -- MAPK@1: 0.6666666666666666 -- MAPK@5: 0.7166666666666667
# gray, rescale=True, 3-12, default, 1, correlation -- MAPK@1: 0.6 -- MAPK@5: 0.6511111111111111
# gray, rescale=True, 3-12, default, 1, bhattacharyya -- MAPK@1: 0.7333333333333333 -- MAPK@5: 0.7694444444444445
# gray, rescale=True, 3-12, default, 4, intersection -- MAPK@1: 0.8666666666666667 -- MAPK@5: 0.9083333333333333
# gray, rescale=True, 3-12, default, 4, correlation -- MAPK@1: 0.8333333333333334 -- MAPK@5: 0.8955555555555555
# gray, rescale=True, 3-12, default, 4, bhattacharyya -- MAPK@1: 0.8666666666666667 -- MAPK@5: 0.89
# gray, rescale=True, 3-12, default, 16, intersection -- MAPK@1: 1.0 -- MAPK@5: 1.0
# gray, rescale=True, 3-12, default, 16, correlation -- MAPK@1: 0.9666666666666667 -- MAPK@5: 0.9666666666666667
# gray, rescale=True, 3-12, default, 16, bhattacharyya -- MAPK@1: 1.0 -- MAPK@5: 1.0
# gray, rescale=True, 3-12, default, 64, intersection -- MAPK@1: 1.0 -- MAPK@5: 1.0
# gray, rescale=True, 3-12, default, 64, correlation -- MAPK@1: 0.9666666666666667 -- MAPK@5: 0.9733333333333333
# gray, rescale=True, 3-12, default, 64, bhattacharyya -- MAPK@1: 1.0 -- MAPK@5: 1.0
# gray, rescale=True, 3-12, ror, 1, intersection -- MAPK@1: 0.16666666666666666 -- MAPK@5: 0.24555555555555555
# gray, rescale=True, 3-12, ror, 1, correlation -- MAPK@1: 0.2 -- MAPK@5: 0.23444444444444443
# gray, rescale=True, 3-12, ror, 1, bhattacharyya -- MAPK@1: 0.3333333333333333 -- MAPK@5: 0.36777777777777776
# gray, rescale=True, 3-12, ror, 4, intersection -- MAPK@1: 0.36666666666666664 -- MAPK@5: 0.41944444444444445
# gray, rescale=True, 3-12, ror, 4, correlation -- MAPK@1: 0.4 -- MAPK@5: 0.44
# gray, rescale=True, 3-12, ror, 4, bhattacharyya -- MAPK@1: 0.4 -- MAPK@5: 0.4805555555555555
# gray, rescale=True, 3-12, ror, 16, intersection -- MAPK@1: 0.6666666666666666 -- MAPK@5: 0.6944444444444444
# gray, rescale=True, 3-12, ror, 16, correlation -- MAPK@1: 0.6333333333333333 -- MAPK@5: 0.675
# gray, rescale=True, 3-12, ror, 16, bhattacharyya -- MAPK@1: 0.6666666666666666 -- MAPK@5: 0.6833333333333333
# gray, rescale=True, 3-12, ror, 64, intersection -- MAPK@1: 0.8 -- MAPK@5: 0.8333333333333334
# gray, rescale=True, 3-12, ror, 64, correlation -- MAPK@1: 0.8666666666666667 -- MAPK@5: 0.8833333333333333
# gray, rescale=True, 3-12, ror, 64, bhattacharyya -- MAPK@1: 0.6666666666666666 -- MAPK@5: 0.7233333333333333
# gray, rescale=True, 3-12, uniform, 1, intersection -- MAPK@1: 0.16666666666666666 -- MAPK@5: 0.17777777777777776
# gray, rescale=True, 3-12, uniform, 1, correlation -- MAPK@1: 0.16666666666666666 -- MAPK@5: 0.19499999999999998
# gray, rescale=True, 3-12, uniform, 1, bhattacharyya -- MAPK@1: 0.16666666666666666 -- MAPK@5: 0.18333333333333332
# gray, rescale=True, 3-12, uniform, 4, intersection -- MAPK@1: 0.3333333333333333 -- MAPK@5: 0.36777777777777776
# gray, rescale=True, 3-12, uniform, 4, correlation -- MAPK@1: 0.36666666666666664 -- MAPK@5: 0.4166666666666667
# gray, rescale=True, 3-12, uniform, 4, bhattacharyya -- MAPK@1: 0.4 -- MAPK@5: 0.415
# gray, rescale=True, 3-12, uniform, 16, intersection -- MAPK@1: 0.5333333333333333 -- MAPK@5: 0.5833333333333334
# gray, rescale=True, 3-12, uniform, 16, correlation -- MAPK@1: 0.6666666666666666 -- MAPK@5: 0.7166666666666667
# gray, rescale=True, 3-12, uniform, 16, bhattacharyya -- MAPK@1: 0.5333333333333333 -- MAPK@5: 0.6027777777777777
# gray, rescale=True, 3-12, uniform, 64, intersection -- MAPK@1: 0.8333333333333334 -- MAPK@5: 0.85
# gray, rescale=True, 3-12, uniform, 64, correlation -- MAPK@1: 0.8333333333333334 -- MAPK@5: 0.8722222222222221
# gray, rescale=True, 3-12, uniform, 64, bhattacharyya -- MAPK@1: 0.8 -- MAPK@5: 0.8166666666666667
# L, rescale=True, 1-8, default, 1, intersection -- MAPK@1: 0.23333333333333334 -- MAPK@5: 0.29
# L, rescale=True, 1-8, default, 1, correlation -- MAPK@1: 0.23333333333333334 -- MAPK@5: 0.28
# L, rescale=True, 1-8, default, 1, bhattacharyya -- MAPK@1: 0.3 -- MAPK@5: 0.3427777777777778
# L, rescale=True, 1-8, default, 4, intersection -- MAPK@1: 0.4666666666666667 -- MAPK@5: 0.48333333333333334
# L, rescale=True, 1-8, default, 4, correlation -- MAPK@1: 0.43333333333333335 -- MAPK@5: 0.47777777777777775
# L, rescale=True, 1-8, default, 4, bhattacharyya -- MAPK@1: 0.5 -- MAPK@5: 0.5222222222222223
# L, rescale=True, 1-8, default, 16, intersection -- MAPK@1: 0.6 -- MAPK@5: 0.6388888888888888
# L, rescale=True, 1-8, default, 16, correlation -- MAPK@1: 0.5666666666666667 -- MAPK@5: 0.5927777777777777
# L, rescale=True, 1-8, default, 16, bhattacharyya -- MAPK@1: 0.6 -- MAPK@5: 0.6288888888888889
# L, rescale=True, 1-8, default, 64, intersection -- MAPK@1: 0.8666666666666667 -- MAPK@5: 0.9138888888888889
# L, rescale=True, 1-8, default, 64, correlation -- MAPK@1: 0.7666666666666667 -- MAPK@5: 0.8244444444444444
# L, rescale=True, 1-8, default, 64, bhattacharyya -- MAPK@1: 0.8333333333333334 -- MAPK@5: 0.8733333333333334
# L, rescale=True, 1-8, ror, 1, intersection -- MAPK@1: 0.06666666666666667 -- MAPK@5: 0.08888888888888888
# L, rescale=True, 1-8, ror, 1, correlation -- MAPK@1: 0.06666666666666667 -- MAPK@5: 0.09000000000000001
# L, rescale=True, 1-8, ror, 1, bhattacharyya -- MAPK@1: 0.1 -- MAPK@5: 0.11111111111111112
# L, rescale=True, 1-8, ror, 4, intersection -- MAPK@1: 0.23333333333333334 -- MAPK@5: 0.24444444444444444
# L, rescale=True, 1-8, ror, 4, correlation -- MAPK@1: 0.2 -- MAPK@5: 0.21666666666666667
# L, rescale=True, 1-8, ror, 4, bhattacharyya -- MAPK@1: 0.23333333333333334 -- MAPK@5: 0.2511111111111111
# L, rescale=True, 1-8, ror, 16, intersection -- MAPK@1: 0.36666666666666664 -- MAPK@5: 0.3927777777777778
# L, rescale=True, 1-8, ror, 16, correlation -- MAPK@1: 0.36666666666666664 -- MAPK@5: 0.39444444444444443
# L, rescale=True, 1-8, ror, 16, bhattacharyya -- MAPK@1: 0.3333333333333333 -- MAPK@5: 0.35666666666666663
# L, rescale=True, 1-8, ror, 64, intersection -- MAPK@1: 0.4666666666666667 -- MAPK@5: 0.5
# L, rescale=True, 1-8, ror, 64, correlation -- MAPK@1: 0.4666666666666667 -- MAPK@5: 0.5111111111111112
# L, rescale=True, 1-8, ror, 64, bhattacharyya -- MAPK@1: 0.5 -- MAPK@5: 0.5177777777777778
# L, rescale=True, 1-8, uniform, 1, intersection -- MAPK@1: 0.06666666666666667 -- MAPK@5: 0.075
# L, rescale=True, 1-8, uniform, 1, correlation -- MAPK@1: 0.06666666666666667 -- MAPK@5: 0.075
# L, rescale=True, 1-8, uniform, 1, bhattacharyya -- MAPK@1: 0.06666666666666667 -- MAPK@5: 0.07777777777777777
# L, rescale=True, 1-8, uniform, 4, intersection -- MAPK@1: 0.2 -- MAPK@5: 0.22333333333333333
# L, rescale=True, 1-8, uniform, 4, correlation -- MAPK@1: 0.2 -- MAPK@5: 0.2361111111111111
# L, rescale=True, 1-8, uniform, 4, bhattacharyya -- MAPK@1: 0.2 -- MAPK@5: 0.21666666666666667
# L, rescale=True, 1-8, uniform, 16, intersection -- MAPK@1: 0.3 -- MAPK@5: 0.34555555555555556
# L, rescale=True, 1-8, uniform, 16, correlation -- MAPK@1: 0.3333333333333333 -- MAPK@5: 0.375
# L, rescale=True, 1-8, uniform, 16, bhattacharyya -- MAPK@1: 0.3333333333333333 -- MAPK@5: 0.35666666666666663
# L, rescale=True, 1-8, uniform, 64, intersection -- MAPK@1: 0.4666666666666667 -- MAPK@5: 0.49166666666666664
# L, rescale=True, 1-8, uniform, 64, correlation -- MAPK@1: 0.5 -- MAPK@5: 0.5333333333333333
# L, rescale=True, 1-8, uniform, 64, bhattacharyya -- MAPK@1: 0.4666666666666667 -- MAPK@5: 0.49166666666666664
# L, rescale=True, 2-10, default, 1, intersection -- MAPK@1: 0.5 -- MAPK@5: 0.5383333333333333
# L, rescale=True, 2-10, default, 1, correlation -- MAPK@1: 0.4 -- MAPK@5: 0.4583333333333333
# L, rescale=True, 2-10, default, 1, bhattacharyya -- MAPK@1: 0.5333333333333333 -- MAPK@5: 0.5661111111111111
# L, rescale=True, 2-10, default, 4, intersection -- MAPK@1: 0.6666666666666666 -- MAPK@5: 0.7166666666666667
# L, rescale=True, 2-10, default, 4, correlation -- MAPK@1: 0.7 -- MAPK@5: 0.725
# L, rescale=True, 2-10, default, 4, bhattacharyya -- MAPK@1: 0.7333333333333333 -- MAPK@5: 0.7611111111111111
# L, rescale=True, 2-10, default, 16, intersection -- MAPK@1: 0.9 -- MAPK@5: 0.9333333333333333
# L, rescale=True, 2-10, default, 16, correlation -- MAPK@1: 0.8666666666666667 -- MAPK@5: 0.9138888888888889
# L, rescale=True, 2-10, default, 16, bhattacharyya -- MAPK@1: 0.8 -- MAPK@5: 0.85
# L, rescale=True, 2-10, default, 64, intersection -- MAPK@1: 1.0 -- MAPK@5: 1.0
# L, rescale=True, 2-10, default, 64, correlation -- MAPK@1: 1.0 -- MAPK@5: 1.0
# L, rescale=True, 2-10, default, 64, bhattacharyya -- MAPK@1: 1.0 -- MAPK@5: 1.0
# L, rescale=True, 2-10, ror, 1, intersection -- MAPK@1: 0.13333333333333333 -- MAPK@5: 0.1788888888888889
# L, rescale=True, 2-10, ror, 1, correlation -- MAPK@1: 0.13333333333333333 -- MAPK@5: 0.18166666666666667
# L, rescale=True, 2-10, ror, 1, bhattacharyya -- MAPK@1: 0.16666666666666666 -- MAPK@5: 0.21333333333333335
# L, rescale=True, 2-10, ror, 4, intersection -- MAPK@1: 0.3333333333333333 -- MAPK@5: 0.36111111111111105
# L, rescale=True, 2-10, ror, 4, correlation -- MAPK@1: 0.3333333333333333 -- MAPK@5: 0.3705555555555556
# L, rescale=True, 2-10, ror, 4, bhattacharyya -- MAPK@1: 0.3333333333333333 -- MAPK@5: 0.3983333333333333
# L, rescale=True, 2-10, ror, 16, intersection -- MAPK@1: 0.5 -- MAPK@5: 0.5083333333333333
# L, rescale=True, 2-10, ror, 16, correlation -- MAPK@1: 0.5 -- MAPK@5: 0.5344444444444444
# L, rescale=True, 2-10, ror, 16, bhattacharyya -- MAPK@1: 0.5 -- MAPK@5: 0.5083333333333333
# L, rescale=True, 2-10, ror, 64, intersection -- MAPK@1: 0.6333333333333333 -- MAPK@5: 0.7194444444444444
# L, rescale=True, 2-10, ror, 64, correlation -- MAPK@1: 0.7 -- MAPK@5: 0.7483333333333333
# L, rescale=True, 2-10, ror, 64, bhattacharyya -- MAPK@1: 0.6 -- MAPK@5: 0.6316666666666666
# L, rescale=True, 2-10, uniform, 1, intersection -- MAPK@1: 0.1 -- MAPK@5: 0.12777777777777777
# L, rescale=True, 2-10, uniform, 1, correlation -- MAPK@1: 0.1 -- MAPK@5: 0.11777777777777777
# L, rescale=True, 2-10, uniform, 1, bhattacharyya -- MAPK@1: 0.1 -- MAPK@5: 0.14
# L, rescale=True, 2-10, uniform, 4, intersection -- MAPK@1: 0.3 -- MAPK@5: 0.3233333333333333
# L, rescale=True, 2-10, uniform, 4, correlation -- MAPK@1: 0.26666666666666666 -- MAPK@5: 0.3
# L, rescale=True, 2-10, uniform, 4, bhattacharyya -- MAPK@1: 0.3 -- MAPK@5: 0.3416666666666667
# L, rescale=True, 2-10, uniform, 16, intersection -- MAPK@1: 0.4666666666666667 -- MAPK@5: 0.49
# L, rescale=True, 2-10, uniform, 16, correlation -- MAPK@1: 0.5333333333333333 -- MAPK@5: 0.5911111111111111
# L, rescale=True, 2-10, uniform, 16, bhattacharyya -- MAPK@1: 0.4666666666666667 -- MAPK@5: 0.4983333333333333
# L, rescale=True, 2-10, uniform, 64, intersection -- MAPK@1: 0.6 -- MAPK@5: 0.6472222222222221
# L, rescale=True, 2-10, uniform, 64, correlation -- MAPK@1: 0.7333333333333333 -- MAPK@5: 0.7566666666666666
# L, rescale=True, 2-10, uniform, 64, bhattacharyya -- MAPK@1: 0.6 -- MAPK@5: 0.6427777777777777
# L, rescale=True, 3-12, default, 1, intersection -- MAPK@1: 0.6666666666666666 -- MAPK@5: 0.711111111111111
# L, rescale=True, 3-12, default, 1, correlation -- MAPK@1: 0.6333333333333333 -- MAPK@5: 0.6694444444444444
# L, rescale=True, 3-12, default, 1, bhattacharyya -- MAPK@1: 0.7 -- MAPK@5: 0.7344444444444443
# L, rescale=True, 3-12, default, 4, intersection -- MAPK@1: 0.9 -- MAPK@5: 0.925
# L, rescale=True, 3-12, default, 4, correlation -- MAPK@1: 0.8 -- MAPK@5: 0.8722222222222221
# L, rescale=True, 3-12, default, 4, bhattacharyya -- MAPK@1: 0.8666666666666667 -- MAPK@5: 0.8944444444444444
# L, rescale=True, 3-12, default, 16, intersection -- MAPK@1: 1.0 -- MAPK@5: 1.0
# L, rescale=True, 3-12, default, 16, correlation -- MAPK@1: 0.9666666666666667 -- MAPK@5: 0.9666666666666667
# L, rescale=True, 3-12, default, 16, bhattacharyya -- MAPK@1: 1.0 -- MAPK@5: 1.0
# L, rescale=True, 3-12, default, 64, intersection -- MAPK@1: 1.0 -- MAPK@5: 1.0
# L, rescale=True, 3-12, default, 64, correlation -- MAPK@1: 0.9333333333333333 -- MAPK@5: 0.9611111111111111
# L, rescale=True, 3-12, default, 64, bhattacharyya -- MAPK@1: 1.0 -- MAPK@5: 1.0
# L, rescale=True, 3-12, ror, 1, intersection -- MAPK@1: 0.2 -- MAPK@5: 0.2594444444444444
# L, rescale=True, 3-12, ror, 1, correlation -- MAPK@1: 0.16666666666666666 -- MAPK@5: 0.23
# L, rescale=True, 3-12, ror, 1, bhattacharyya -- MAPK@1: 0.26666666666666666 -- MAPK@5: 0.3194444444444444
# L, rescale=True, 3-12, ror, 4, intersection -- MAPK@1: 0.36666666666666664 -- MAPK@5: 0.41388888888888886
# L, rescale=True, 3-12, ror, 4, correlation -- MAPK@1: 0.43333333333333335 -- MAPK@5: 0.45111111111111113
# L, rescale=True, 3-12, ror, 4, bhattacharyya -- MAPK@1: 0.43333333333333335 -- MAPK@5: 0.5027777777777778
# L, rescale=True, 3-12, ror, 16, intersection -- MAPK@1: 0.6666666666666666 -- MAPK@5: 0.6944444444444444
# L, rescale=True, 3-12, ror, 16, correlation -- MAPK@1: 0.6333333333333333 -- MAPK@5: 0.6861111111111111
# L, rescale=True, 3-12, ror, 16, bhattacharyya -- MAPK@1: 0.6333333333333333 -- MAPK@5: 0.6733333333333333
# L, rescale=True, 3-12, ror, 64, intersection -- MAPK@1: 0.8 -- MAPK@5: 0.8483333333333333
# L, rescale=True, 3-12, ror, 64, correlation -- MAPK@1: 0.8666666666666667 -- MAPK@5: 0.89
# L, rescale=True, 3-12, ror, 64, bhattacharyya -- MAPK@1: 0.6666666666666666 -- MAPK@5: 0.711111111111111
# L, rescale=True, 3-12, uniform, 1, intersection -- MAPK@1: 0.1 -- MAPK@5: 0.1527777777777778
# L, rescale=True, 3-12, uniform, 1, correlation -- MAPK@1: 0.1 -- MAPK@5: 0.1411111111111111
# L, rescale=True, 3-12, uniform, 1, bhattacharyya -- MAPK@1: 0.13333333333333333 -- MAPK@5: 0.17333333333333334
# L, rescale=True, 3-12, uniform, 4, intersection -- MAPK@1: 0.3333333333333333 -- MAPK@5: 0.3533333333333334
# L, rescale=True, 3-12, uniform, 4, correlation -- MAPK@1: 0.3 -- MAPK@5: 0.39777777777777784
# L, rescale=True, 3-12, uniform, 4, bhattacharyya -- MAPK@1: 0.36666666666666664 -- MAPK@5: 0.40277777777777773
# L, rescale=True, 3-12, uniform, 16, intersection -- MAPK@1: 0.5333333333333333 -- MAPK@5: 0.576111111111111
# L, rescale=True, 3-12, uniform, 16, correlation -- MAPK@1: 0.7 -- MAPK@5: 0.74
# L, rescale=True, 3-12, uniform, 16, bhattacharyya -- MAPK@1: 0.5333333333333333 -- MAPK@5: 0.5955555555555556
# L, rescale=True, 3-12, uniform, 64, intersection -- MAPK@1: 0.8333333333333334 -- MAPK@5: 0.85
# L, rescale=True, 3-12, uniform, 64, correlation -- MAPK@1: 0.8333333333333334 -- MAPK@5: 0.8816666666666666
# L, rescale=True, 3-12, uniform, 64, bhattacharyya -- MAPK@1: 0.7666666666666667 -- MAPK@5: 0.8111111111111111
# V, rescale=True, 1-8, default, 1, intersection -- MAPK@1: 0.23333333333333334 -- MAPK@5: 0.2827777777777778
# V, rescale=True, 1-8, default, 1, correlation -- MAPK@1: 0.2 -- MAPK@5: 0.25277777777777777
# V, rescale=True, 1-8, default, 1, bhattacharyya -- MAPK@1: 0.3 -- MAPK@5: 0.33166666666666667
# V, rescale=True, 1-8, default, 4, intersection -- MAPK@1: 0.4 -- MAPK@5: 0.44166666666666665
# V, rescale=True, 1-8, default, 4, correlation -- MAPK@1: 0.4 -- MAPK@5: 0.4555555555555556
# V, rescale=True, 1-8, default, 4, bhattacharyya -- MAPK@1: 0.43333333333333335 -- MAPK@5: 0.5
# V, rescale=True, 1-8, default, 16, intersection -- MAPK@1: 0.6 -- MAPK@5: 0.6066666666666667
# V, rescale=True, 1-8, default, 16, correlation -- MAPK@1: 0.5666666666666667 -- MAPK@5: 0.59
# V, rescale=True, 1-8, default, 16, bhattacharyya -- MAPK@1: 0.6 -- MAPK@5: 0.615
# V, rescale=True, 1-8, default, 64, intersection -- MAPK@1: 0.8333333333333334 -- MAPK@5: 0.9
# V, rescale=True, 1-8, default, 64, correlation -- MAPK@1: 0.7666666666666667 -- MAPK@5: 0.8333333333333334
# V, rescale=True, 1-8, default, 64, bhattacharyya -- MAPK@1: 0.8 -- MAPK@5: 0.8611111111111112
# V, rescale=True, 1-8, ror, 1, intersection -- MAPK@1: 0.06666666666666667 -- MAPK@5: 0.07333333333333333
# V, rescale=True, 1-8, ror, 1, correlation -- MAPK@1: 0.06666666666666667 -- MAPK@5: 0.07333333333333333
# V, rescale=True, 1-8, ror, 1, bhattacharyya -- MAPK@1: 0.06666666666666667 -- MAPK@5: 0.08444444444444446
# V, rescale=True, 1-8, ror, 4, intersection -- MAPK@1: 0.2 -- MAPK@5: 0.225
# V, rescale=True, 1-8, ror, 4, correlation -- MAPK@1: 0.2 -- MAPK@5: 0.2222222222222222
# V, rescale=True, 1-8, ror, 4, bhattacharyya -- MAPK@1: 0.23333333333333334 -- MAPK@5: 0.24444444444444444
# V, rescale=True, 1-8, ror, 16, intersection -- MAPK@1: 0.3333333333333333 -- MAPK@5: 0.36666666666666664
# V, rescale=True, 1-8, ror, 16, correlation -- MAPK@1: 0.3333333333333333 -- MAPK@5: 0.38333333333333336
# V, rescale=True, 1-8, ror, 16, bhattacharyya -- MAPK@1: 0.3333333333333333 -- MAPK@5: 0.35833333333333334
# V, rescale=True, 1-8, ror, 64, intersection -- MAPK@1: 0.4 -- MAPK@5: 0.46111111111111114
# V, rescale=True, 1-8, ror, 64, correlation -- MAPK@1: 0.5 -- MAPK@5: 0.5194444444444445
# V, rescale=True, 1-8, ror, 64, bhattacharyya -- MAPK@1: 0.4 -- MAPK@5: 0.45555555555555555
# V, rescale=True, 1-8, uniform, 1, intersection -- MAPK@1: 0.06666666666666667 -- MAPK@5: 0.07333333333333333
# V, rescale=True, 1-8, uniform, 1, correlation -- MAPK@1: 0.06666666666666667 -- MAPK@5: 0.06666666666666667
# V, rescale=True, 1-8, uniform, 1, bhattacharyya -- MAPK@1: 0.06666666666666667 -- MAPK@5: 0.07333333333333333
# V, rescale=True, 1-8, uniform, 4, intersection -- MAPK@1: 0.2 -- MAPK@5: 0.21944444444444444
# V, rescale=True, 1-8, uniform, 4, correlation -- MAPK@1: 0.16666666666666666 -- MAPK@5: 0.20666666666666667
# V, rescale=True, 1-8, uniform, 4, bhattacharyya -- MAPK@1: 0.2 -- MAPK@5: 0.20833333333333334
# V, rescale=True, 1-8, uniform, 16, intersection -- MAPK@1: 0.3 -- MAPK@5: 0.3466666666666667
# V, rescale=True, 1-8, uniform, 16, correlation -- MAPK@1: 0.3333333333333333 -- MAPK@5: 0.3611111111111111
# V, rescale=True, 1-8, uniform, 16, bhattacharyya -- MAPK@1: 0.3333333333333333 -- MAPK@5: 0.35833333333333334
# V, rescale=True, 1-8, uniform, 64, intersection -- MAPK@1: 0.4 -- MAPK@5: 0.4444444444444444
# V, rescale=True, 1-8, uniform, 64, correlation -- MAPK@1: 0.4666666666666667 -- MAPK@5: 0.5
# V, rescale=True, 1-8, uniform, 64, bhattacharyya -- MAPK@1: 0.4666666666666667 -- MAPK@5: 0.4944444444444444
# V, rescale=True, 2-10, default, 1, intersection -- MAPK@1: 0.3333333333333333 -- MAPK@5: 0.44
# V, rescale=True, 2-10, default, 1, correlation -- MAPK@1: 0.3 -- MAPK@5: 0.38166666666666665
# V, rescale=True, 2-10, default, 1, bhattacharyya -- MAPK@1: 0.5 -- MAPK@5: 0.5277777777777778
# V, rescale=True, 2-10, default, 4, intersection -- MAPK@1: 0.6666666666666666 -- MAPK@5: 0.7083333333333334
# V, rescale=True, 2-10, default, 4, correlation -- MAPK@1: 0.6333333333333333 -- MAPK@5: 0.7055555555555555
# V, rescale=True, 2-10, default, 4, bhattacharyya -- MAPK@1: 0.6333333333333333 -- MAPK@5: 0.6861111111111111
# V, rescale=True, 2-10, default, 16, intersection -- MAPK@1: 0.8666666666666667 -- MAPK@5: 0.9111111111111111
# V, rescale=True, 2-10, default, 16, correlation -- MAPK@1: 0.8666666666666667 -- MAPK@5: 0.925
# V, rescale=True, 2-10, default, 16, bhattacharyya -- MAPK@1: 0.7666666666666667 -- MAPK@5: 0.8277777777777777
# V, rescale=True, 2-10, default, 64, intersection -- MAPK@1: 1.0 -- MAPK@5: 1.0
# V, rescale=True, 2-10, default, 64, correlation -- MAPK@1: 1.0 -- MAPK@5: 1.0
# V, rescale=True, 2-10, default, 64, bhattacharyya -- MAPK@1: 1.0 -- MAPK@5: 1.0
# V, rescale=True, 2-10, ror, 1, intersection -- MAPK@1: 0.1 -- MAPK@5: 0.14444444444444443
# V, rescale=True, 2-10, ror, 1, correlation -- MAPK@1: 0.1 -- MAPK@5: 0.15
# V, rescale=True, 2-10, ror, 1, bhattacharyya -- MAPK@1: 0.1 -- MAPK@5: 0.16222222222222224
# V, rescale=True, 2-10, ror, 4, intersection -- MAPK@1: 0.26666666666666666 -- MAPK@5: 0.30666666666666664
# V, rescale=True, 2-10, ror, 4, correlation -- MAPK@1: 0.2 -- MAPK@5: 0.2638888888888889
# V, rescale=True, 2-10, ror, 4, bhattacharyya -- MAPK@1: 0.3 -- MAPK@5: 0.34833333333333333
# V, rescale=True, 2-10, ror, 16, intersection -- MAPK@1: 0.4666666666666667 -- MAPK@5: 0.49444444444444446
# V, rescale=True, 2-10, ror, 16, correlation -- MAPK@1: 0.36666666666666664 -- MAPK@5: 0.44166666666666665
# V, rescale=True, 2-10, ror, 16, bhattacharyya -- MAPK@1: 0.4666666666666667 -- MAPK@5: 0.48333333333333334
# V, rescale=True, 2-10, ror, 64, intersection -- MAPK@1: 0.6666666666666666 -- MAPK@5: 0.7122222222222222
# V, rescale=True, 2-10, ror, 64, correlation -- MAPK@1: 0.6333333333333333 -- MAPK@5: 0.7055555555555555
# V, rescale=True, 2-10, ror, 64, bhattacharyya -- MAPK@1: 0.6 -- MAPK@5: 0.6388888888888888
# V, rescale=True, 2-10, uniform, 1, intersection -- MAPK@1: 0.03333333333333333 -- MAPK@5: 0.09166666666666666
# V, rescale=True, 2-10, uniform, 1, correlation -- MAPK@1: 0.06666666666666667 -- MAPK@5: 0.10277777777777777
# V, rescale=True, 2-10, uniform, 1, bhattacharyya -- MAPK@1: 0.1 -- MAPK@5: 0.13444444444444445
# V, rescale=True, 2-10, uniform, 4, intersection -- MAPK@1: 0.16666666666666666 -- MAPK@5: 0.21777777777777776
# V, rescale=True, 2-10, uniform, 4, correlation -- MAPK@1: 0.23333333333333334 -- MAPK@5: 0.26666666666666666
# V, rescale=True, 2-10, uniform, 4, bhattacharyya -- MAPK@1: 0.2 -- MAPK@5: 0.2427777777777778
# V, rescale=True, 2-10, uniform, 16, intersection -- MAPK@1: 0.36666666666666664 -- MAPK@5: 0.4111111111111111
# V, rescale=True, 2-10, uniform, 16, correlation -- MAPK@1: 0.5 -- MAPK@5: 0.5583333333333333
# V, rescale=True, 2-10, uniform, 16, bhattacharyya -- MAPK@1: 0.43333333333333335 -- MAPK@5: 0.46499999999999997
# V, rescale=True, 2-10, uniform, 64, intersection -- MAPK@1: 0.6 -- MAPK@5: 0.6472222222222223
# V, rescale=True, 2-10, uniform, 64, correlation -- MAPK@1: 0.7 -- MAPK@5: 0.7333333333333333
# V, rescale=True, 2-10, uniform, 64, bhattacharyya -- MAPK@1: 0.5666666666666667 -- MAPK@5: 0.6333333333333333
# V, rescale=True, 3-12, default, 1, intersection -- MAPK@1: 0.6 -- MAPK@5: 0.6555555555555554
# V, rescale=True, 3-12, default, 1, correlation -- MAPK@1: 0.5333333333333333 -- MAPK@5: 0.591111111111111
# V, rescale=True, 3-12, default, 1, bhattacharyya -- MAPK@1: 0.6333333333333333 -- MAPK@5: 0.6944444444444444
# V, rescale=True, 3-12, default, 4, intersection -- MAPK@1: 0.9 -- MAPK@5: 0.9149999999999999
# V, rescale=True, 3-12, default, 4, correlation -- MAPK@1: 0.9 -- MAPK@5: 0.9166666666666666
# V, rescale=True, 3-12, default, 4, bhattacharyya -- MAPK@1: 0.8333333333333334 -- MAPK@5: 0.8555555555555555
# V, rescale=True, 3-12, default, 16, intersection -- MAPK@1: 1.0 -- MAPK@5: 1.0
# V, rescale=True, 3-12, default, 16, correlation -- MAPK@1: 0.9333333333333333 -- MAPK@5: 0.9666666666666667
# V, rescale=True, 3-12, default, 16, bhattacharyya -- MAPK@1: 0.9666666666666667 -- MAPK@5: 0.9833333333333333
# V, rescale=True, 3-12, default, 64, intersection -- MAPK@1: 1.0 -- MAPK@5: 1.0
# V, rescale=True, 3-12, default, 64, correlation -- MAPK@1: 1.0 -- MAPK@5: 1.0
# V, rescale=True, 3-12, default, 64, bhattacharyya -- MAPK@1: 1.0 -- MAPK@5: 1.0
# V, rescale=True, 3-12, ror, 1, intersection -- MAPK@1: 0.2 -- MAPK@5: 0.24444444444444444
# V, rescale=True, 3-12, ror, 1, correlation -- MAPK@1: 0.2 -- MAPK@5: 0.21111111111111114
# V, rescale=True, 3-12, ror, 1, bhattacharyya -- MAPK@1: 0.26666666666666666 -- MAPK@5: 0.3
# V, rescale=True, 3-12, ror, 4, intersection -- MAPK@1: 0.3 -- MAPK@5: 0.3511111111111111
# V, rescale=True, 3-12, ror, 4, correlation -- MAPK@1: 0.26666666666666666 -- MAPK@5: 0.31111111111111106
# V, rescale=True, 3-12, ror, 4, bhattacharyya -- MAPK@1: 0.3 -- MAPK@5: 0.35944444444444446
# V, rescale=True, 3-12, ror, 16, intersection -- MAPK@1: 0.5333333333333333 -- MAPK@5: 0.6277777777777778
# V, rescale=True, 3-12, ror, 16, correlation -- MAPK@1: 0.5 -- MAPK@5: 0.5916666666666667
# V, rescale=True, 3-12, ror, 16, bhattacharyya -- MAPK@1: 0.6 -- MAPK@5: 0.6483333333333333
# V, rescale=True, 3-12, ror, 64, intersection -- MAPK@1: 0.8333333333333334 -- MAPK@5: 0.861111111111111
# V, rescale=True, 3-12, ror, 64, correlation -- MAPK@1: 0.8333333333333334 -- MAPK@5: 0.8666666666666667
# V, rescale=True, 3-12, ror, 64, bhattacharyya -- MAPK@1: 0.7 -- MAPK@5: 0.7527777777777778
# V, rescale=True, 3-12, uniform, 1, intersection -- MAPK@1: 0.1 -- MAPK@5: 0.12777777777777777
# V, rescale=True, 3-12, uniform, 1, correlation -- MAPK@1: 0.13333333333333333 -- MAPK@5: 0.15777777777777777
# V, rescale=True, 3-12, uniform, 1, bhattacharyya -- MAPK@1: 0.13333333333333333 -- MAPK@5: 0.1611111111111111
# V, rescale=True, 3-12, uniform, 4, intersection -- MAPK@1: 0.23333333333333334 -- MAPK@5: 0.26666666666666666
# V, rescale=True, 3-12, uniform, 4, correlation -- MAPK@1: 0.26666666666666666 -- MAPK@5: 0.32611111111111113
# V, rescale=True, 3-12, uniform, 4, bhattacharyya -- MAPK@1: 0.23333333333333334 -- MAPK@5: 0.27777777777777773
# V, rescale=True, 3-12, uniform, 16, intersection -- MAPK@1: 0.36666666666666664 -- MAPK@5: 0.4577777777777778
# V, rescale=True, 3-12, uniform, 16, correlation -- MAPK@1: 0.7 -- MAPK@5: 0.725
# V, rescale=True, 3-12, uniform, 16, bhattacharyya -- MAPK@1: 0.4666666666666667 -- MAPK@5: 0.5372222222222223
# V, rescale=True, 3-12, uniform, 64, intersection -- MAPK@1: 0.8 -- MAPK@5: 0.8416666666666667
# V, rescale=True, 3-12, uniform, 64, correlation -- MAPK@1: 0.8333333333333334 -- MAPK@5: 0.8666666666666667
# V, rescale=True, 3-12, uniform, 64, bhattacharyya -- MAPK@1: 0.8 -- MAPK@5: 0.8444444444444444

# %%
def multiple_lbp(num_blocks_list = [16, 64],
                 color = "L",
                 rescale = True,
                 radius = "Multi",
                 points = "Multi",
                 method = "default",
                 distance_measure = "bhattacharyya"):
    
    # Save results in a list, which will then be transformed into a df
    full_results = []
    
    # Load query images
    query_images = load_images_from_directory(query_folder)

    # Load bbdd images
    bbdd_images = load_images_from_directory(bbdd_folder)
    
    # Load groundtruth
    gt_dir = os.path.join(query_folder, 'gt_corresps.pkl')
    with open(gt_dir, 'rb') as reader:
        ground_truth = pickle.load(reader)
        
    query_images_color = transform_images_color_space(query_images, color_space=color)
    bbdd_images_color = transform_images_color_space(bbdd_images, color_space=color)
    
    query_images_color = rescale_images(query_images_color, (256, 256))
    bbdd_images_color = rescale_images(bbdd_images_color, (256, 256))
    
    for num_blocks in num_blocks_list:
        
        query_lbp_vectors = compute_images_block_multi_lbp(query_images_color, method, num_blocks)
        bbdd_lbp_vectors = compute_images_block_multi_lbp(bbdd_images_color, method, num_blocks)

        print(f"{num_blocks}", end=" ")

        # Calculate distance matrix
        distance_matrix = create_distance_matrix(query_lbp_vectors, 
                                                 bbdd_lbp_vectors,
                                                 distance_measure,
                                                 normalize=None)
        # Generate sorted results
        results = generate_results(distance_matrix, distance_measure)

        # Calculate metrics
        mapk_val_1 = mapk(ground_truth, results, 1)
        mapk_val_5 = mapk(ground_truth, results, 5)

        # Print metrics for current combination
        print(f"-- MAPK@{1}: {mapk_val_1} -- MAPK@{5}: {mapk_val_5}")

        # Save current combination parameters and results
        combination_results = {}
        combination_results['Color'] = color
        combination_results['Rescale'] = rescale
        combination_results['Radius'] = radius
        combination_results['Points'] = points
        combination_results['Method'] = method
        combination_results['Blocks'] = num_blocks
        combination_results['Distance'] = distance_measure
        combination_results['MAP@1'] = mapk_val_1
        combination_results['MAP@5'] = mapk_val_5
        full_results.append(combination_results)
    
    # Save results
    full_results_df = pd.DataFrame(full_results)
    full_results_df.to_csv("multiple_lbp_results.csv", index=False)
    
    return full_results_df

# %%
multiple_lbp_results_df = multiple_lbp()
# Out:
# 16 -- MAPK@1: 0.8333333333333334 -- MAPK@5: 0.9055555555555554
# 64 -- MAPK@1: 1.0 -- MAPK@5: 1.0

# %%
# !pip list
# Out:
# Package                            Version
# WARNING: Ignoring invalid distribution -illow (c:\users\donai\anaconda3\lib\site-packages)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ---------------------------------- --------------------
# absl-py                            1.0.0
# affine                             2.4.0
# alabaster                          0.7.12
# altgraph                           0.17
# anaconda-client                    1.7.2
# anaconda-navigator                 2.3.2
# anaconda-project                   0.9.1
# annoy                              1.17.1
# anyio                              2.2.0
# appdirs                            1.4.4
# argh                               0.26.2
# argon2-cffi                        20.1.0
# asn1crypto                         1.4.0
# astroid                            2.5
# astropy                            5.2.2
# astunparse                         1.6.3
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              20.3.0
# auto-py-to-exe                     2.22.0
# Automat                            20.2.0
# autopep8                           1.5.6
# Babel                              2.9.0
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.4
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# bcrypt                             3.2.0
# beautifulsoup4                     4.9.3
# bitarray                           1.9.2
# bkcharts                           0.2
# black                              19.10b0
# bleach                             3.3.0
# blis                               0.7.9
# bokeh                              2.3.2
# boto                               2.49.0
# bottle                             0.12.23
# bottle-websocket                   0.2.9
# Bottleneck                         1.3.2
# brotlipy                           0.7.0
# cachetools                         5.0.0
# catalogue                          2.0.8
# certifi                            2023.5.7
# cffi                               1.14.5
# chardet                            4.0.0
# click                              8.1.3
# click-plugins                      1.1.1
# cligj                              0.7.2
# clldutils                          3.19.0
# cloudpickle                        1.6.0
# clyent                             1.2.2
# colorama                           0.4.6
# colorlog                           6.7.0
# comtypes                           1.1.9
# conda                              22.9.0
# conda-build                        3.23.3
# conda-content-trust                0.1.3
# conda-package-handling             1.9.0
# conda-repo-cli                     1.0.4
# conda-token                        0.4.0
# conda-verify                       3.4.2
# confection                         0.0.4
# constantly                         15.1.0
# contextlib2                        0.6.0.post1
# coverage                           5.5
# cryptography                       3.4.7
# cssselect                          1.1.0
# csvw                               3.1.3
# cycler                             0.10.0
# cymem                              2.0.7
# Cython                             0.29.23
# cytoolz                            0.11.0
# dask                               2021.4.0
# decorator                          5.0.9
# deep-phonemizer                    0.0.19
# defusedxml                         0.7.1
# deprecation                        2.1.0
# diff-match-patch                   20200713
# distributed                        2021.4.0
# dlinfo                             1.2.1
# docker-pycreds                     0.4.0
# docopt                             0.6.2
# docutils                           0.17
# dqsegdb2                           1.2.1
# Eel                                0.14.0
# en-core-web-sm                     3.5.0
# entrypoints                        0.3
# et-xmlfile                         1.0.1
# eyed3                              0.9.6
# fastcache                          1.1.0
# filelock                           3.0.12
# filetype                           1.0.7
# fiona                              1.9.6
# fire                               0.5.0
# flake8                             3.9.0
# Flask                              1.1.2
# flatbuffers                        2.0
# fonttools                          4.53.0
# fsspec                             0.9.0
# future                             0.18.2
# gast                               0.5.3
# GDAL                               2.3.3
# geopandas                          0.13.2
# gevent                             21.1.2
# gevent-websocket                   0.10.1
# gitdb                              4.0.10
# GitPython                          3.1.31
# glob2                              0.7
# gmpy2                              2.1.2
# google-auth                        2.6.0
# google-auth-oauthlib               0.4.6
# google-pasta                       0.2.0
# graphviz                           0.20.1
# greenlet                           1.0.0
# grpcio                             1.44.0
# gwdatafind                         1.2.0
# gwosc                              0.7.1
# gwpy                               3.0.7
# h5py                               3.11.0
# HeapDict                           1.0.1
# hiddenlayer                        0.3
# html5lib                           1.1
# hyperlink                          21.0.0
# icon-font-to-png                   0.4.1
# idna                               2.10
# igwn-auth-utils                    1.1.0
# imagecodecs                        2021.3.31
# imageio                            2.9.0
# imagesize                          1.2.0
# importlib-metadata                 4.11.2
# incremental                        21.3.0
# iniconfig                          1.1.1
# intervaltree                       3.1.0
# ipykernel                          5.3.4
# ipython                            7.22.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.6.3
# isodate                            0.6.1
# isort                              5.8.0
# itemadapter                        0.4.0
# itemloaders                        1.0.4
# itsdangerous                       1.1.0
# jdcal                              1.4.1
# jedi                               0.17.2
# Jinja2                             2.11.3
# jmespath                           0.10.0
# joblib                             1.0.1
# json5                              0.9.5
# jsonschema                         3.2.0
# jupyter                            1.0.0
# jupyter-client                     6.1.12
# jupyter-console                    6.4.0
# jupyter-core                       4.7.1
# jupyter-packaging                  0.7.12
# jupyter-server                     1.4.1
# jupyterlab                         3.0.14
# jupyterlab-pygments                0.1.2
# jupyterlab-server                  2.4.0
# jupyterlab-widgets                 1.0.0
# kaggle                             1.5.13
# keras                              2.8.0
# Keras-Preprocessing                1.1.2
# keyring                            22.3.0
# kiwisolver                         1.3.1
# langcodes                          3.3.0
# language-tags                      1.2.0
# laspy                              2.4.1
# laszip                             0.2.2
# lazrs                              0.5.0
# lazy-object-proxy                  1.6.0
# Levenshtein                        0.25.1
# libarchive-c                       2.9
# libclang                           13.0.0
# ligo-segments                      1.4.0
# ligotimegps                        2.0.1
# llvmlite                           0.36.0
# locket                             0.2.1
# lxml                               4.6.3
# Markdown                           3.3.6
# MarkupSafe                         1.1.1
# matplotlib                         3.5.3
# mccabe                             0.6.1
# menuinst                           1.4.16
# missingno                          0.5.1
# mistune                            0.8.4
# mkl-fft                            1.3.0
# mkl-random                         1.2.1
# mkl-service                        2.3.0
# mock                               4.0.3
# more-itertools                     8.7.0
# MouseInfo                          0.1.3
# mpmath                             1.2.1
# msgpack                            1.0.2
# multipledispatch                   0.6.0
# murmurhash                         1.0.9
# mypy-extensions                    0.4.3
# mysql-connector-python             8.0.26
# navigator-updater                  0.2.1
# nbclassic                          0.2.6
# nbclient                           0.5.3
# nbconvert                          6.0.7
# nbformat                           5.1.3
# nest-asyncio                       1.5.1
# networkx                           2.5
# nltk                               3.6.1
# nose                               1.3.7
# notebook                           6.3.0
# numba                              0.53.1
# numexpr                            2.7.3
# numpy                              1.20.1
# numpydoc                           1.1.0
# oauthlib                           3.2.0
# olefile                            0.46
# opencv-contrib-python              4.5.3.56
# opencv-contrib-python-headless     4.5.3.56
# opencv-python                      4.5.3.56
# openpyxl                           3.0.7
# opt-einsum                         3.3.0
# packaging                          22.0
# palettable                         3.3.3
# pandas                             1.4.3
# pandocfilters                      1.4.3
# paramiko                           2.7.2
# parsel                             1.6.0
# parso                              0.7.0
# partd                              1.2.0
# path                               15.1.2
# pathlib2                           2.3.5
# pathspec                           0.7.0
# pathtools                          0.1.2
# pathy                              0.10.1
# patsy                              0.5.1
# pefile                             2022.5.30
# pep8                               1.7.1
# pexpect                            4.8.0
# phonemizer                         3.2.1
# pickleshare                        0.7.5
# Pillow                             9.5.0
# pip                                23.2.1
# pkginfo                            1.7.0
# plotly                             5.8.0
# pluggy                             0.13.1
# ply                                3.11
# preshed                            3.0.8
# prettytable                        3.5.0
# prometheus-client                  0.10.1
# prompt-toolkit                     3.0.17
# Protego                            0.2.1
# protobuf                           3.19.4
# psutil                             5.8.0
# ptyprocess                         0.7.0
# py                                 1.10.0
# pyaml                              21.10.1
# pyasn1                             0.4.8
# pyasn1-modules                     0.2.8
# PyAutoGUI                          0.9.54
# pycodestyle                        2.6.0
# pycosat                            0.6.3
# pycparser                          2.20
# pycryptodome                       3.20.0
# pycurl                             7.43.0.6
# pydantic                           1.10.7
# PyDispatcher                       2.0.5
# pydocstyle                         6.0.0
# pyerfa                             2.0.0.3
# pyflakes                           2.2.0
# pygame                             2.0.1
# PyGetWindow                        0.0.9
# Pygments                           2.8.1
# pyinstaller                        5.3
# pyinstaller-hooks-contrib          2022.10
# PyJWT                              2.4.0
# pylatexenc                         2.10
# pylint                             2.7.4
# pyls-black                         0.4.6
# pyls-spyder                        0.3.2
# PyMsgBox                           1.0.9
# PyNaCl                             1.4.0
# pyodbc                             4.0.0-unsupported
# pyOpenSSL                          20.0.1
# pyparsing                          2.4.7
# pyperclip                          1.8.2
# pyproj                             3.5.0
# pyreadline                         2.1
# PyRect                             0.2.0
# pyrsistent                         0.17.3
# PyScreeze                          0.1.30
# PySimpleGUI                        4.60.3
# PySocks                            1.7.1
# pytest                             6.2.3
# python-dateutil                    2.8.1
# python-jsonrpc-server              0.4.0
# python-language-server             0.36.2
# python-slugify                     8.0.1
# pytweening                         1.2.0
# pytz                               2021.1
# PyWavelets                         1.1.1
# pywhatkit                          5.4
# pywin32                            227
# pywin32-ctypes                     0.2.0
# pywinpty                           0.5.7
# PyYAML                             5.4.1
# pyzmq                              20.0.0
# QDarkStyle                         2.8.1
# QtAwesome                          1.0.2
# qtconsole                          5.0.3
# QtPy                               1.9.0
# queuelib                           1.6.2
# rapidfuzz                          3.9.7
# rasterio                           1.3.6
# rdflib                             6.3.2
# regex                              2021.4.4
# requests                           2.25.1
# requests-file                      1.5.1
# requests-oauthlib                  1.3.1
# rfc3986                            1.5.0
# rope                               0.18.0
# rsa                                4.8
# Rtree                              0.9.7
# ruamel-yaml-conda                  0.15.100
# safe-netrc                         1.0.1
# scikit-image                       0.18.1
# scikit-learn                       0.24.1
# scikit-optimize                    0.9.0
# scipy                              1.6.2
# scitokens                          1.8.1
# Scrapy                             2.6.1
# seaborn                            0.11.1
# segments                           2.2.1
# Send2Trash                         1.5.0
# sentry-sdk                         1.23.0
# service-identity                   21.1.0
# setproctitle                       1.3.2
# setuptools                         67.7.2
# shap                               0.41.0
# shapely                            2.0.4
# simplegeneric                      0.8.1
# singledispatch                     0.0.0
# sip                                4.19.13
# six                                1.15.0
# slicer                             0.0.7
# smart-open                         6.3.0
# smmap                              5.0.0
# sniffio                            1.2.0
# snowballstemmer                    2.1.0
# snuggs                             1.4.7
# sortedcollections                  2.1.0
# sortedcontainers                   2.3.0
# soupsieve                          2.2.1
# spacy                              3.5.3
# spacy-legacy                       3.0.12
# spacy-loggers                      1.0.4
# Sphinx                             4.0.1
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             1.0.3
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.4
# sphinxcontrib-websupport           1.2.4
# spyder                             4.2.5
# spyder-kernels                     1.10.2
# SQLAlchemy                         1.4.7
# srsly                              2.4.6
# statsmodels                        0.12.2
# stylecloud                         0.5.2
# sympy                              1.8
# tables                             3.6.1
# tabulate                           0.9.0
# tblib                              1.7.0
# tenacity                           8.0.1
# tensorboard                        2.8.0
# tensorboard-data-server            0.6.1
# tensorboard-plugin-wit             1.8.1
# tensorflow                         2.8.0
# tensorflow-io-gcs-filesystem       0.24.0
# termcolor                          1.1.0
# terminado                          0.9.4
# testpath                           0.4.4
# text-unidecode                     1.3
# textdistance                       4.2.1
# tf-estimator-nightly               2.8.0.dev2021122109
# thinc                              8.1.10
# thop                               0.1.1.post2209072238
# threadpoolctl                      2.1.0
# three-merge                        0.1.1
# tifffile                           2021.4.8
# tinycss                            0.4
# tldextract                         3.2.0
# toml                               0.10.2
# toolz                              0.11.1
# torch                              1.12.1
# torchaudio                         0.12.1
# torchvision                        0.13.1
# torchviz                           0.0.2
# tornado                            6.1
# tqdm                               4.59.0
# traitlets                          5.0.5
# Twisted                            22.1.0
# twisted-iocpsupport                1.0.2
# typed-ast                          1.4.2
# typer                              0.7.0
# typing_extensions                  4.5.0
# ujson                              4.0.2
# unicodecsv                         0.14.1
# uritemplate                        4.1.1
# urllib3                            1.26.4
# w3lib                              1.22.0
# wandb                              0.15.2
# wasabi                             1.1.1
# watchdog                           1.0.2
# wcwidth                            0.2.5
# webencodings                       0.5.1
# Werkzeug                           1.0.1
# wheel                              0.40.0
# whichcraft                         0.6.1
# widgetsnbextension                 3.5.1
# wikipedia                          1.4.0
# win-inet-pton                      1.1.0
# win-unicode-console                0.5
# wincertstore                       0.2
# wordcloud                          1.9.2
# wrapt                              1.12.1
# wxPython                           4.1.1
# xgboost                            1.6.2
# xlrd                               2.0.1
# XlsxWriter                         1.3.8
# xlwings                            0.23.0
# xlwt                               1.3.0
# xmltodict                          0.12.0
# yapf                               0.31.0
# zict                               2.0.0
# zipp                               3.4.1
# zope.event                         4.5.0
# zope.interface                     5.3.0
